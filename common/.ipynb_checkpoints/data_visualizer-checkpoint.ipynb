# %% [markdown]
# ### Data visualizer to explore data ranges and experiment with data values
#
# ![Greedybusiness](/home/jeffreymo572/Kaggles/common/images/Monopoly.jpg)

# %%
# Importing
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sn
import holidays

# Dataset
data_dir = "~/Kaggles/data/S3E7/train.csv"
df = pd.read_csv(data_dir)

# %%
# Column info
df.info()

# %%
df.head(10)

# %%
# Renaming columns to be more readable
# Current unknowns: market_segment_type, 
df.columns = ["id", 'num_adults', 'num_children', 'num_weekend_nights', 'num_week_nights', 'meal_plan', 
              'parking', 'room_type', 'lead_time', 'year', 'month', 'date', 'market_segment_type', 'repeated_customer',
              'num_prev_cancellations', 'num_prev_not_cancelled', 'avg_price_per_room', 'num_special_requests',
              'booking_status']

for i, value in enumerate(df.columns.tolist()):
    print(f"{i}: {value}")
# Out:
# 0: id
# 1: num_adults
# 2: num_children
# 3: num_weekend_nights
# 4: num_week_nights
# 5: meal_plan
# 6: parking
# 7: room_type
# 8: lead_time
# 9: year
# 10: month
# 11: date
# 12: market_segment_type
# 13: repeated_customer
# 14: num_prev_cancellations
# 15: num_prev_not_cancelled
# 16: avg_price_per_room
# 17: num_special_requests
# 18: booking_status

# %% [markdown]
# #### Possible Notes for cleaning
# ##### Additions
# * Insert ratio of cancellations at index 16
#     * `num_prev_cancellations/(num_prev_not_cancelled+avg_price_per_room)`
# * Is weekend
#     * `pd.Timestamp(f"{year}-{month:.2f}-{day:.2f}").dayofweek`
#     * Note: Monday is 0
# * Is holiday
#     * Might have to hard code: https://en.wikipedia.org/wiki/Federal_holidays_in_the_United_States
# * Total people
#     * `num_adults+num_children`
# ##### Removals
# * ID (done)
# * date -> weekday & holiday
# ##### Modifications
# * Month/Year/Date into one column?
#     * Maybe not since month/year may have seasonal impact on cancellation
#
# ##### Questionable
# * Parking
# * meal_plan
#
# # KNOWN CORRELATIONS
# **PEOPLE WHO ORDER MEAL PLAN 3 HAVE A 83% CHANCE TO CANCEL!!!** \
# **PEOPLE WITH A BOOKING STATUS OF 0 WILL CANCEL!!!!**

# %%
# Information about data 
# Mean, median, mode, variance, std, etc.
df_info = pd.DataFrame()

df_info['var'] = df.var()
df_info['mean'] = df.mean()
df_info['std'] = df.std()
df_info['var/mean'] = df.var()/df.mean()
df_info['std/mean'] = df.std()/df.mean()

df_info.reset_index(inplace=True)
df_info.columns = ['category', 'var', 'mean', 'std', 'var/mean', 'std/mean']

# Dropping and replacing values
df_info = df_info.drop(0)

df_info
# Out:
#                   category          var         mean        std   var/mean  \
# 1               num_adults     0.275573     1.920713   0.524950   0.143474
# 2             num_children     0.202615     0.141093   0.450128   1.436046
# 3       num_weekend_nights     0.784452     0.884632   0.885693   0.886756
# 4          num_week_nights     2.037270     2.398005   1.427330   0.849569
# 5                meal_plan     0.345361     0.239192   0.587674   1.443861
# 6                  parking     0.024612     0.025249   0.156884   0.974774
# 7                room_type     0.693232     0.428931   0.832605   1.616184
# 8                lead_time  6572.238347   103.888029  81.069343  63.262711
# 9                     year     0.123057  2017.856295   0.350795   0.000061
# 10                   month     8.005479     7.593539   2.829395   1.054249
# 11                    date    79.006899    15.902945   8.888582   4.968067
# 12     market_segment_type     0.401359     0.728504   0.633529   0.550936
# 13       repeated_customer     0.028341     0.029192   0.168347   0.970831
# 14  num_prev_cancellations     0.106170     0.019715   0.325837   5.385232
# 15  num_prev_not_cancelled     3.000244     0.175772   1.732121  17.068958
# 16      avg_price_per_room  1379.317583   104.566377  37.139165  13.190833
# 17    num_special_requests     0.600688     0.571734   0.775041   1.050642
# 18          booking_status     0.238346     0.392019   0.488207   0.607995
#
#      std/mean
# 1    0.273310
# 2    3.190303
# 3    1.001200
# 4    0.595216
# 5    2.456908
# 6    6.213357
# 7    1.941117
# 8    0.780353
# 9    0.000174
# 10   0.372606
# 11   0.558927
# 12   0.869630
# 13   5.766826
# 14  16.527388
# 15   9.854366
# 16   0.355173
# 17   1.355597
# 18   1.245365

# %%
df['norm_adults'] = df["num_adults"]/max(df['num_adults'])
df
# Out:
#           id  num_adults  num_children  num_weekend_nights  num_week_nights  \
# 0          0           2             0                   0                2
# 1          1           2             0                   1                2
# 2          2           2             0                   0                1
# 3          3           1             0                   0                2
# 4          4           2             0                   1                0
# ...      ...         ...           ...                 ...              ...
# 42095  42095           3             0                   0                4
# 42096  42096           2             0                   0                3
# 42097  42097           2             0                   0                2
# 42098  42098           1             0                   0                3
# 42099  42099           2             0                   1                1
#
#        meal_plan  parking  room_type  lead_time  year  month  date  \
# 0              1        0          0          9  2018      1    14
# 1              0        0          0        117  2018      7    29
# 2              0        0          0        315  2018     12     2
# 3              1        0          0         32  2018     12     1
# 4              0        0          0        258  2018     10    16
# ...          ...      ...        ...        ...   ...    ...   ...
# 42095          0        0          1        160  2018     12    30
# 42096          0        0          0         34  2017      9    23
# 42097          2        0          0        292  2018      7    21
# 42098          0        0          0          5  2018     11     9
# 42099          0        0          1         40  2017     10    26
#
#        market_segment_type  repeated_customer  num_prev_cancellations  \
# 0                        1                  1                      11
# 1                        0                  0                       0
# 2                        0                  0                       0
# 3                        1                  0                       0
# 4                        0                  0                       0
# ...                    ...                ...                     ...
# 42095                    1                  0                       0
# 42096                    0                  0                       0
# 42097                    0                  0                       0
# 42098                    0                  0                       0
# 42099                    0                  0                       0
#
#        num_prev_not_cancelled  avg_price_per_room  num_special_requests  \
# 0                           0               67.50                     0
# 1                           0               72.25                     0
# 2                           0               52.00                     0
# 3                           0               56.00                     0
# 4                           0              100.00                     0
# ...                       ...                 ...                   ...
# 42095                       0              140.00                     2
# 42096                       0              224.67                     0
# 42097                       0               96.00                     0
# 42098                       0              120.00                     0
# 42099                       0               65.00                     0
#
#        booking_status  norm_adults
# 0                   0         0.50
# 1                   0         0.50
# 2                   0         0.50
# 3                   0         0.25
# 4                   1         0.50
# ...               ...          ...
# 42095               1         0.75
# 42096               0         0.50
# 42097               0         0.50
# 42098               0         0.25
# 42099               0         0.50
#
# [42100 rows x 20 columns]

# %%
# Holiday checker
month = df['month']
year = df['year']
day = df['date']
us_holidays = holidays.UnitedStates()
df['is_holiday'] = f"{year}-{month}-{day}" in us_holidays
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File ~/anaconda3/envs/Kaggles/lib/python3.8/site-packages/holidays/holiday_base.py:309, in HolidayBase.__keytransform__(self, key)
#     308 try:
# --> 309     out_key = parse(key).date()
#     310 except (ValueError, OverflowError):
#
# File ~/anaconda3/envs/Kaggles/lib/python3.8/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~/anaconda3/envs/Kaggles/lib/python3.8/site-packages/dateutil/parser/_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#
# ParserError: Unknown string format: 0        2018
# 1        2018
# 2        2018
# 3        2018
# 4        2018
#          ...
# 42095    2018
# 42096    2017
# 42097    2018
# 42098    2018
# 42099    2017
# Name: year, Length: 42100, dtype: int64-0         1
# 1         7
# 2        12
# 3        12
# 4        10
#          ..
# 42095    12
# 42096     9
# 42097     7
# 42098    11
# 42099    10
# Name: month, Length: 42100, dtype: int64-0        14
# 1        29
# 2         2
# 3         1
# 4        16
#          ..
# 42095    30
# 42096    23
# 42097    21
# 42098     9
# 42099    26
# Name: date, Length: 42100, dtype: int64
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       4 day = df['date']
#       5 us_holidays = holidays.UnitedStates()
# ----> 6 df['is_holiday'] = f"{year}-{month}-{day}" in us_holidays
#
# File ~/anaconda3/envs/Kaggles/lib/python3.8/site-packages/holidays/holiday_base.py:335, in HolidayBase.__contains__(self, key)
#     331 if not isinstance(key, (date, datetime, str, float, int)):
#     332     raise TypeError("Cannot convert type '%s' to date." % type(key))
#     334 return dict.__contains__(
# --> 335     cast("Mapping[Any, Any]", self), self.__keytransform__(key)
#     336 )
#
# File ~/anaconda3/envs/Kaggles/lib/python3.8/site-packages/holidays/holiday_base.py:311, in HolidayBase.__keytransform__(self, key)
#     309         out_key = parse(key).date()
#     310     except (ValueError, OverflowError):
# --> 311         raise ValueError("Cannot parse date from string '%s'" % key)
#     312 else:
#     313     raise TypeError("Cannot convert type '%s' to date." % type(key))
#
# ValueError: Cannot parse date from string '0        2018
# 1        2018
# 2        2018
# 3        2018
# 4        2018
#          ...
# 42095    2018
# 42096    2017
# 42097    2018
# 42098    2018
# 42099    2017
# Name: year, Length: 42100, dtype: int64-0         1
# 1         7
# 2        12
# 3        12
# 4        10
#          ..
# 42095    12
# 42096     9
# 42097     7
# 42098    11
# 42099    10
# Name: month, Length: 42100, dtype: int64-0        14
# 1        29
# 2         2
# 3         1
# 4        16
#          ..
# 42095    30
# 42096    23
# 42097    21
# 42098     9
# 42099    26
# Name: date, Length: 42100, dtype: int64'
